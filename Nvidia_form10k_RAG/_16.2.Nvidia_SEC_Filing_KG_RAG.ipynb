# %% [markdown]
# * https://pypi.org/project/sec-api/#description
# * https://sec-api.io/profile

# %%
# SEC API
from sec_api import QueryApi, XbrlApi, ExtractorApi, MappingApi
# environment variables
import os
from dotenv import load_dotenv
# data processing
import json
import textwrap
from bs4 import BeautifulSoup
import pandas as pd

from tqdm import tqdm

# Langchain
from langchain_community.graphs import Neo4jGraph
from langchain_community.vectorstores import Neo4jVector
# from langchain_openai import OpenAIEmbeddings
from langchain_community.embeddings.ollama import OllamaEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.qa_with_sources.retrieval import RetrievalQAWithSourcesChain
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq

load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. Get Form 10K - run just ONCE!!

# %% [markdown]
# #### Get 10K url

# %%
queryApi = QueryApi(os.getenv('SEC_API_KEY2'))

# %%
ticker = "NVDA"
query = {
  "query": { "query_string": { 
      "query": f"formType:\"10-K\" AND ticker:{ticker}", # only 10-Ks
  }},
  "from": "0", # start returning matches from position null, i.e. the first matching filing 
  "size": "1"  # return just one filing
}

# %%
response = queryApi.get_filings(query)

# %%
response
# Out:
# {'total': {'value': 26, 'relation': 'eq'},
#  'query': {'from': 0, 'size': 1},
#  'filings': [{'id': '946a233fb0d9d28c95b372bdda12d004',
#    'accessionNo': '0001045810-24-000029',
#    'cik': '1045810',
#    'ticker': 'NVDA',
#    'companyName': 'NVIDIA CORP',
#    'companyNameLong': 'NVIDIA CORP (Filer)',
#    'formType': '10-K',
#    'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#    'filedAt': '2024-02-21T16:36:57-05:00',
#    'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029.txt',
#    'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029-index.htm',
#    'linkToXbrl': '',
#    'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm',
#    'entities': [{'companyName': 'NVIDIA CORP (Filer)',
#      'cik': '1045810',
#      'irsNo': '943177549',
#      'stateOfIncorporation': 'DE',
#      'fiscalYearEnd': '0128',
#      'type': '10-K',
#      'act': '34',
#      'fileNo': '000-23985',
#      'filmNo': '24660316',
#      'sic': '3674 Semiconductors &amp; Related Devices'}],
#    'documentFormatFiles': [{'sequence': '1',
#      'description': '10-K',
#      'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm',
#      'type': '10-K',
#      'size': '2085566'},
#     {'sequence': '2',
#      'description': 'SUBSIDIARIES OF REGISTRANT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/subsidiariesofregistrantfy.htm',
#      'type': 'EX-21.1',
#      'size': '3597'},
#     {'sequence': '3',
#      'description': 'CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/consentofindependentregist.htm',
#      'type': 'EX-23.1',
#      'size': '2323'},
#     {'sequence': '4',
#      'description': '302 CERTIFICATION OF CEO',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex311.htm',
#      'type': 'EX-31.1',
#      'size': '8601'},
#     {'sequence': '5',
#      'description': '302 CERTIFICATION OF CFO',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex312.htm',
#      'type': 'EX-31.2',
#      'size': '8448'},
#     {'sequence': '6',
#      'description': '906 CERTIFICATION OF CEO',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex321.htm',
#      'type': 'EX-32.1',
#      'size': '5777'},
#     {'sequence': '7',
#      'description': '906 CERTIFICATION OF CFO',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex322.htm',
#      'type': 'EX-32.2',
#      'size': '5548'},
#     {'sequence': '8',
#      'description': 'COMPENSATION RECOVERY POLICY',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/compensationrecoverypolicy.htm',
#      'type': 'EX-97.1',
#      'size': '51308'},
#     {'sequence': '14',
#      'description': 'NVDA LOGO 1',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/image_0.jpg',
#      'type': 'GRAPHIC',
#      'size': '63541'},
#     {'sequence': '15',
#      'description': 'NVDA LOGO 2',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_g1.jpg',
#      'type': 'GRAPHIC',
#      'size': '7474'},
#     {'sequence': '16',
#      'description': '5YR STOCK PERFORMANCE GRAPH',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_g2.jpg',
#      'type': 'GRAPHIC',
#      'size': '127075'},
#     {'sequence': '\xa0',
#      'description': 'Complete submission text file',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029.txt',
#      'type': '\xa0',
#      'size': '11813809'}],
#    'dataFiles': [{'sequence': '9',
#      'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.xsd',
#      'type': 'EX-101.SCH',
#      'size': '67840'},
#     {'sequence': '10',
#      'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_cal.xml',
#      'type': 'EX-101.CAL',
#      'size': '135289'},
#     {'sequence': '11',
#      'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_def.xml',
#      'type': 'EX-101.DEF',
#      'size': '322611'},
#     {'sequence': '12',
#      'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_lab.xml',
#      'type': 'EX-101.LAB',
#      'size': '993109'},
#     {'sequence': '13',
#      'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_pre.xml',
#      'type': 'EX-101.PRE',
#      'size': '648012'},
#     {'sequence': '116',
#      'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#      'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_htm.xml',
#      'type': 'XML',
#      'size': '1831322'}],
#    'seriesAndClassesContractsInformation': [],
#    'periodOfReport': '2024-01-28'}]}

# %%
response["total"]
# Out:
# {'value': 26, 'relation': 'eq'}

# %%
filings = response["filings"][0]
filings
# Out:
# {'id': '946a233fb0d9d28c95b372bdda12d004',
#  'accessionNo': '0001045810-24-000029',
#  'cik': '1045810',
#  'ticker': 'NVDA',
#  'companyName': 'NVIDIA CORP',
#  'companyNameLong': 'NVIDIA CORP (Filer)',
#  'formType': '10-K',
#  'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]',
#  'filedAt': '2024-02-21T16:36:57-05:00',
#  'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029.txt',
#  'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029-index.htm',
#  'linkToXbrl': '',
#  'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm',
#  'entities': [{'companyName': 'NVIDIA CORP (Filer)',
#    'cik': '1045810',
#    'irsNo': '943177549',
#    'stateOfIncorporation': 'DE',
#    'fiscalYearEnd': '0128',
#    'type': '10-K',
#    'act': '34',
#    'fileNo': '000-23985',
#    'filmNo': '24660316',
#    'sic': '3674 Semiconductors &amp; Related Devices'}],
#  'documentFormatFiles': [{'sequence': '1',
#    'description': '10-K',
#    'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm',
#    'type': '10-K',
#    'size': '2085566'},
#   {'sequence': '2',
#    'description': 'SUBSIDIARIES OF REGISTRANT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/subsidiariesofregistrantfy.htm',
#    'type': 'EX-21.1',
#    'size': '3597'},
#   {'sequence': '3',
#    'description': 'CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/consentofindependentregist.htm',
#    'type': 'EX-23.1',
#    'size': '2323'},
#   {'sequence': '4',
#    'description': '302 CERTIFICATION OF CEO',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex311.htm',
#    'type': 'EX-31.1',
#    'size': '8601'},
#   {'sequence': '5',
#    'description': '302 CERTIFICATION OF CFO',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex312.htm',
#    'type': 'EX-31.2',
#    'size': '8448'},
#   {'sequence': '6',
#    'description': '906 CERTIFICATION OF CEO',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex321.htm',
#    'type': 'EX-32.1',
#    'size': '5777'},
#   {'sequence': '7',
#    'description': '906 CERTIFICATION OF CFO',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-2024xex322.htm',
#    'type': 'EX-32.2',
#    'size': '5548'},
#   {'sequence': '8',
#    'description': 'COMPENSATION RECOVERY POLICY',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/compensationrecoverypolicy.htm',
#    'type': 'EX-97.1',
#    'size': '51308'},
#   {'sequence': '14',
#    'description': 'NVDA LOGO 1',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/image_0.jpg',
#    'type': 'GRAPHIC',
#    'size': '63541'},
#   {'sequence': '15',
#    'description': 'NVDA LOGO 2',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_g1.jpg',
#    'type': 'GRAPHIC',
#    'size': '7474'},
#   {'sequence': '16',
#    'description': '5YR STOCK PERFORMANCE GRAPH',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_g2.jpg',
#    'type': 'GRAPHIC',
#    'size': '127075'},
#   {'sequence': '\xa0',
#    'description': 'Complete submission text file',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/0001045810-24-000029.txt',
#    'type': '\xa0',
#    'size': '11813809'}],
#  'dataFiles': [{'sequence': '9',
#    'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.xsd',
#    'type': 'EX-101.SCH',
#    'size': '67840'},
#   {'sequence': '10',
#    'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_cal.xml',
#    'type': 'EX-101.CAL',
#    'size': '135289'},
#   {'sequence': '11',
#    'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_def.xml',
#    'type': 'EX-101.DEF',
#    'size': '322611'},
#   {'sequence': '12',
#    'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_lab.xml',
#    'type': 'EX-101.LAB',
#    'size': '993109'},
#   {'sequence': '13',
#    'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_pre.xml',
#    'type': 'EX-101.PRE',
#    'size': '648012'},
#   {'sequence': '116',
#    'description': 'EXTRACTED XBRL INSTANCE DOCUMENT',
#    'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128_htm.xml',
#    'type': 'XML',
#    'size': '1831322'}],
#  'seriesAndClassesContractsInformation': [],
#  'periodOfReport': '2024-01-28'}

# %%
url_10k = filings["linkToFilingDetails"]
url_10k
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm'

# %% [markdown]
# #### Get 10K financial stateatements

# %%
xbrlApi = XbrlApi(os.getenv('SEC_API_KEY2'))
financial_statements_json = xbrlApi.xbrl_to_json(url_10k)

# %%
type(financial_statements_json)
# Out:
# dict

# %%
for k,v in financial_statements_json.items():
    print(k, type(v))
# Out:
# CoverPage <class 'dict'>
# AuditInformation <class 'dict'>
# StatementsOfIncome <class 'dict'>
# StatementsOfComprehensiveIncome <class 'dict'>
# BalanceSheets <class 'dict'>
# BalanceSheetsParenthetical <class 'dict'>
# StatementsOfShareholdersEquity <class 'dict'>
# StatementsOfShareholdersEquityParenthetical <class 'dict'>
# StatementsOfCashFlows <class 'dict'>
# OrganizationandSummaryofSignificantAccountingPolicies <class 'dict'>
# BusinessCombination <class 'dict'>
# Leases <class 'dict'>
# StockBasedCompensation <class 'dict'>
# NetIncomePerShare <class 'dict'>
# Goodwill <class 'dict'>
# AmortizableIntangibleAssets <class 'dict'>
# CashEquivalentsandMarketableSecurities <class 'dict'>
# FairValueofFinancialAssetsandLiabilitiesandInvestmentsinNonAffiliatedEntities <class 'dict'>
# BalanceSheetComponents <class 'dict'>
# DerivativeFinancialInstruments <class 'dict'>
# Debt <class 'dict'>
# CommitmentsandContingencies <class 'dict'>
# IncomeTaxes <class 'dict'>
# ShareholdersEquity <class 'dict'>
# EmployeeRetirementPlans <class 'dict'>
# SegmentInformation <class 'dict'>
# ScheduleIIValuationandQualifyingAccounts <class 'dict'>
# OrganizationandSummaryofSignificantAccountingPoliciesPolicies <class 'dict'>
# LeasesTables <class 'dict'>
# StockBasedCompensationTables <class 'dict'>
# NetIncomePerShareTables <class 'dict'>
# AmortizableIntangibleAssetsTables <class 'dict'>
# CashEquivalentsandMarketableSecuritiesTables <class 'dict'>
# FairValueofFinancialAssetsandLiabilitiesandInvestmentsinNonAffiliatedEntitiesTables <class 'dict'>
# BalanceSheetComponentsTables <class 'dict'>
# DerivativeFinancialInstrumentsTables <class 'dict'>
# DebtTables <class 'dict'>
# CommitmentsandContingenciesTables <class 'dict'>
# IncomeTaxesTables <class 'dict'>
# SegmentInformationTables <class 'dict'>
# OrganizationandSummaryofSignificantAccountingPoliciesDetails <class 'dict'>
# BusinessCombinationDetails <class 'dict'>
# LeasesScheduleofFutureMinimumLeasePaymentsDetails <class 'dict'>
# LeasesNarrativeDetails <class 'dict'>
# LeasesScheduleofotherleaseinformationDetails <class 'dict'>
# StockBasedCompensationScheduleofStockBasedCompensationExpenseDetails <class 'dict'>
# StockBasedCompensationSummaryofEquityAwardsDetails <class 'dict'>
# StockBasedCompensationNarrativeDetails <class 'dict'>
# StockBasedCompensationEquityIncentivePlansDetails <class 'dict'>
# NetIncomePerShareDetails <class 'dict'>
# GoodwillDetails <class 'dict'>
# AmortizableIntangibleAssetsDetails <class 'dict'>
# CashEquivalentsandMarketableSecuritiesCashEquivalentsandMarketableSecuritiesDetails <class 'dict'>
# CashEquivalentsandMarketableSecuritiesUnrealizedLossesAggregatedbyInvestmentCategoryDetails <class 'dict'>
# CashEquivalentsandMarketableSecuritiesAmortizedCostandEstimatedFairValueofCashEquivalentsandMarketableSecuritiesDetails <class 'dict'>
# FairValueofFinancialAssetsandLiabilitiesandInvestmentsinNonAffiliatedEntitiesDetails <class 'dict'>
# FairValueofFinancialAssetsandLiabilitiesandInvestmentsinNonAffiliatedEntitiesNarrativeDetails <class 'dict'>
# FairValueofFinancialAssetsandLiabilitiesandInvestmentsinNonAffiliatedEntitiesCarryingValueofNonmarketableEquitySecuritiesDetails <class 'dict'>
# FairValueofFinancialAssetsandLiabilitiesandInvestmentsinNonAffiliatedEntitiesCumulativeGrossDetails <class 'dict'>
# BalanceSheetComponentsInventoriesDetails <class 'dict'>
# BalanceSheetComponentsPropertyandEquipmentDetails <class 'dict'>
# BalanceSheetComponentsNarrativeDetails <class 'dict'>
# BalanceSheetComponentsOtherAssetsDetails <class 'dict'>
# BalanceSheetComponentsAccruedandOtherCurrentLiabilitiesDetails <class 'dict'>
# BalanceSheetComponentsOtherLongTermLiabilitiesDetails <class 'dict'>
# BalanceSheetComponentsDeferredRevenueDetails <class 'dict'>
# BalanceSheetComponentsRevenueRemainingPerformanceObligationDetails <class 'dict'>
# DerivativeFinancialInstrumentsNotionalValueofOurForeignCurrencyForwardContractsOutstandingDetails <class 'dict'>
# DerivativeFinancialInstrumentsNarrativeDetails <class 'dict'>
# DebtNarrativeDetails <class 'dict'>
# DebtScheduleofDebtDetails <class 'dict'>
# CommitmentsandContingenciesNarrativeDetails <class 'dict'>
# CommitmentsandContingenciesSummaryofFutureCommitmentsDuebyYearDetails <class 'dict'>
# CommitmentsandContingenciesScheduleofProductWarrantyLiabilitiesDetails <class 'dict'>
# IncomeTaxesComponentsofIncomeTaxExpenseDetails <class 'dict'>
# IncomeTaxesIncomeTaxReconciliationDetails <class 'dict'>
# IncomeTaxesDeferredTaxesDetails <class 'dict'>
# IncomeTaxesNarrativeDetails <class 'dict'>
# IncomeTaxesUnrecognizedTaxBenefitsDetails <class 'dict'>
# ShareholdersEquityDetails <class 'dict'>
# EmployeeRetirementPlansDetails <class 'dict'>
# SegmentInformationNarrativeDetails <class 'dict'>
# SegmentInformationReportableSegmentsDetails <class 'dict'>
# SegmentInformationReconcilingItemsDetails <class 'dict'>
# SegmentInformationRevenueandLonglivedAssetsbyRegionDetails <class 'dict'>
# SegmentInformationScheduleofRevenuebyMarketDetails <class 'dict'>
# ScheduleIIValuationandQualifyingAccountsDetails <class 'dict'>
# InsiderTradingArrangements <class 'dict'>
# PvpDisclosure <class 'dict'>

# %%
# # Access income statement, balance sheet and cash flow statement
# print(financial_statements_json["StatementsOfIncome"])
# print(financial_statements_json["BalanceSheets"])
# print(financial_statements_json["StatementsOfCashFlows"])

# %%
with open("nvda_10k_2023_fin.json", "w") as f:
    json.dump(financial_statements_json, f, indent=4)

# %% [markdown]
# ##### Standard 10K ToC text
# "message":"10-K item type not supported. Supported items are: {1, 1A, 1B, 1C, 2, 3, 4, 5, 6, 7, 7A, 8, 9, 9A, 9B, 9C, 10, 11, 12, 13, 14, 15"}

# %%
# Table of contents
toc_key = ["1", "1A", "1B", "1C", "2", "3", "4", "5", "6", "7", "7A", "8", 
           "9", "9A", "9B", "9C", "10", "11", "12", "13", "14", "15"]
toc_val = [str('item'+toc_key[x]) for x in range(len(toc_key))]
toc_sectors = dict(zip(toc_key, toc_val))
len(toc_sectors),
# Out:
# (22,)

# %%
extractorApi = ExtractorApi(os.getenv('SEC_API_KEY2'))
sectors = {}

# generate the toc section key value pairs
for k, v in tqdm(toc_sectors.items()):
    # print(k, v)
    sector = extractorApi.get_section(url_10k, k, return_type='text')
    sectors.update({v: sector})
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 100%|██████████| 22/22 [00:28<00:00,  1.27s/it]

# %%
type(sectors)
# Out:
# dict

# %% [markdown]
# ##### Get Company mapping (e.g. cik, sic)

# %%
mappingApi = MappingApi(os.getenv('SEC_API_KEY2'))

# %%
mapping = mappingApi.resolve("ticker", ticker)[0]

# %%
# type(mapping), 
mapping
# Out:
# {'name': 'NVIDIA CORP',
#  'ticker': 'NVDA',
#  'cik': '1045810',
#  'cusip': '67066G104',
#  'exchange': 'NASDAQ',
#  'isDelisted': False,
#  'category': 'Domestic Common Stock',
#  'sector': 'Technology',
#  'industry': 'Semiconductors',
#  'sic': '3674',
#  'sicSector': 'Manufacturing',
#  'sicIndustry': 'Semiconductors & Related Devices',
#  'famaSector': '',
#  'famaIndustry': 'Electronic Equipment',
#  'currency': 'USD',
#  'location': 'California; U.S.A',
#  'id': '4a73b69083f93d38e05e0b76219875c9'}

# %% [markdown]
# ##### Save to file

# %%
nvda_10k_text_json = {}

nvda_10k_text_json.update(mapping)
nvda_10k_text_json.update({'url': url_10k,})
nvda_10k_text_json.update(sectors)

# %%
for k,v in nvda_10k_text_json.items():
    print(k, type(v))
# Out:
# name <class 'str'>
# ticker <class 'str'>
# cik <class 'str'>
# cusip <class 'str'>
# exchange <class 'str'>
# isDelisted <class 'bool'>
# category <class 'str'>
# sector <class 'str'>
# industry <class 'str'>
# sic <class 'str'>
# sicSector <class 'str'>
# sicIndustry <class 'str'>
# famaSector <class 'str'>
# famaIndustry <class 'str'>
# currency <class 'str'>
# location <class 'str'>
# id <class 'str'>
# url <class 'str'>
# item1 <class 'str'>
# item1A <class 'str'>
# item1B <class 'str'>
# item1C <class 'str'>
# item2 <class 'str'>
# item3 <class 'str'>
# item4 <class 'str'>
# item5 <class 'str'>
# item6 <class 'str'>
# item7 <class 'str'>
# item7A <class 'str'>
# item8 <class 'str'>
# item9 <class 'str'>
# item9A <class 'str'>
# item9B <class 'str'>
# item9C <class 'str'>
# item10 <class 'str'>
# item11 <class 'str'>
# item12 <class 'str'>
# item13 <class 'str'>
# item14 <class 'str'>
# item15 <class 'str'>

# %%
with open("nvda_10k_2023.json", "w") as f:
    json.dump(nvda_10k_text_json, f, indent=4)

# %% [markdown]
# ## 2. Check financial statements
# https://medium.com/@jan_5421/extracting-financial-statements-from-sec-filings-xbrl-to-json-f83542ade90

# %%
with open("nvda_10k_2023_fin.json", "r") as f:
    financial_statements_json = json.load(f)

# %% [markdown]
# ##### Income statement

# %%
# convert XBRL-JSON of income statement to pandas dataframe
def get_income_statement(financial_statements_json):
    income_statement_store = {}

    # iterate over each US GAAP item in the income statement
    for usGaapItem in financial_statements_json['StatementsOfIncome']:
        values = []
        indicies = []

        for fact in financial_statements_json['StatementsOfIncome'][usGaapItem]:
            # only consider items without segment. not required for our analysis.
            if 'segment' not in fact:
                index = fact['period']['startDate'] + '-' + fact['period']['endDate']
                # ensure no index duplicates are created
                if index not in indicies:
                    values.append(fact['value'])
                    indicies.append(index)                    

        income_statement_store[usGaapItem] = pd.Series(values, index=indicies) 

    income_statement = pd.DataFrame(income_statement_store)
    # switch columns and rows so that US GAAP items are rows and each column header represents a date range
    return income_statement.T 

income_statement = get_income_statement(financial_statements_json)

income_statement
# Out:
#                                                    2023-01-30-2024-01-28  \
# Revenues                                                     60922000000
# CostOfRevenue                                                16621000000
# GrossProfit                                                  44301000000
# ResearchAndDevelopmentExpense                                 8675000000
# SellingGeneralAndAdministrativeExpense                        2654000000
# BusinessCombinationAdvancedConsiderationWrittenOff                     0
# OperatingExpenses                                            11329000000
# OperatingIncomeLoss                                          32972000000
# InvestmentIncomeInterest                                       866000000
# InterestExpense                                                257000000
# OtherNonoperatingIncomeExpense                                 237000000
# NonoperatingIncomeExpense                                      846000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...           33818000000
# IncomeTaxExpenseBenefit                                       4058000000
# NetIncomeLoss                                                29760000000
# EarningsPerShareBasic                                              12.05
# EarningsPerShareDiluted                                            11.93
# WeightedAverageNumberOfSharesOutstandingBasic                 2469000000
# WeightedAverageNumberOfDilutedSharesOutstanding               2494000000
#
#                                                    2022-01-31-2023-01-29  \
# Revenues                                                     26974000000
# CostOfRevenue                                                11618000000
# GrossProfit                                                  15356000000
# ResearchAndDevelopmentExpense                                 7339000000
# SellingGeneralAndAdministrativeExpense                        2440000000
# BusinessCombinationAdvancedConsiderationWrittenOff            1353000000
# OperatingExpenses                                            11132000000
# OperatingIncomeLoss                                           4224000000
# InvestmentIncomeInterest                                       267000000
# InterestExpense                                                262000000
# OtherNonoperatingIncomeExpense                                 -48000000
# NonoperatingIncomeExpense                                      -43000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            4181000000
# IncomeTaxExpenseBenefit                                       -187000000
# NetIncomeLoss                                                 4368000000
# EarningsPerShareBasic                                               1.76
# EarningsPerShareDiluted                                             1.74
# WeightedAverageNumberOfSharesOutstandingBasic                 2487000000
# WeightedAverageNumberOfDilutedSharesOutstanding               2507000000
#
#                                                    2021-02-01-2022-01-30
# Revenues                                                     26914000000
# CostOfRevenue                                                 9439000000
# GrossProfit                                                  17475000000
# ResearchAndDevelopmentExpense                                 5268000000
# SellingGeneralAndAdministrativeExpense                        2166000000
# BusinessCombinationAdvancedConsiderationWrittenOff                     0
# OperatingExpenses                                             7434000000
# OperatingIncomeLoss                                          10041000000
# InvestmentIncomeInterest                                        29000000
# InterestExpense                                                236000000
# OtherNonoperatingIncomeExpense                                 107000000
# NonoperatingIncomeExpense                                     -100000000
# IncomeLossFromContinuingOperationsBeforeIncomeT...            9941000000
# IncomeTaxExpenseBenefit                                        189000000
# NetIncomeLoss                                                 9752000000
# EarningsPerShareBasic                                               3.91
# EarningsPerShareDiluted                                             3.85
# WeightedAverageNumberOfSharesOutstandingBasic                 2496000000
# WeightedAverageNumberOfDilutedSharesOutstanding               2535000000

# %% [markdown]
# ##### Balance sheet

# %%
# convert XBRL-JSON of balance sheet to pandas dataframe
def get_balance_sheet(financial_statements_json):
    balance_sheet_store = {}

    for usGaapItem in financial_statements_json['BalanceSheets']:
        values = []
        indicies = []

        for fact in financial_statements_json['BalanceSheets'][usGaapItem]:
            # only consider items without segment.
            if 'segment' not in fact:
                index = fact['period']['instant']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue
                    
                # add 0 if value is nil
                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    

            balance_sheet_store[usGaapItem] = pd.Series(values, index=indicies) 

    balance_sheet = pd.DataFrame(balance_sheet_store)
    # switch columns and rows so that US GAAP items are rows and each column header represents a date instant
    return balance_sheet.T

balance_sheet = get_balance_sheet(financial_statements_json)
balance_sheet
# Out:
#                                                   2021-01-31   2022-01-30  \
# CashAndCashEquivalentsAtCarryingValue                    NaN          NaN
# MarketableSecuritiesCurrent                              NaN          NaN
# AccountsReceivableNetCurrent                             NaN          NaN
# InventoryNet                                             NaN          NaN
# PrepaidExpenseAndOtherAssetsCurrent                      NaN          NaN
# AssetsCurrent                                            NaN          NaN
# PropertyPlantAndEquipmentNet                             NaN          NaN
# OperatingLeaseRightOfUseAsset                            NaN          NaN
# Goodwill                                                 NaN          NaN
# IntangibleAssetsNetExcludingGoodwill                     NaN          NaN
# DeferredIncomeTaxAssetsNet                               NaN          NaN
# OtherAssetsNoncurrent                                    NaN          NaN
# Assets                                                   NaN          NaN
# AccountsPayableCurrent                                   NaN          NaN
# AccruedLiabilitiesCurrent                                NaN          NaN
# DebtCurrent                                              NaN          NaN
# LiabilitiesCurrent                                       NaN          NaN
# LongTermDebtNoncurrent                                   NaN          NaN
# OperatingLeaseLiabilityNoncurrent                        NaN          NaN
# OtherLiabilitiesNoncurrent                               NaN          NaN
# Liabilities                                              NaN          NaN
# CommitmentsAndContingencies                              NaN          NaN
# PreferredStockValueOutstanding                           NaN          NaN
# CommonStockValue                                         NaN          NaN
# AdditionalPaidInCapital                                  NaN          NaN
# AccumulatedOtherComprehensiveIncomeLossNetOfTax          NaN          NaN
# RetainedEarningsAccumulatedDeficit                       NaN          NaN
# StockholdersEquity                               16893000000  26612000000
# LiabilitiesAndStockholdersEquity                         NaN          NaN
#
#                                                   2023-01-29   2024-01-28
# CashAndCashEquivalentsAtCarryingValue             3389000000   7280000000
# MarketableSecuritiesCurrent                       9907000000  18704000000
# AccountsReceivableNetCurrent                      3827000000   9999000000
# InventoryNet                                      5159000000   5282000000
# PrepaidExpenseAndOtherAssetsCurrent                791000000   3080000000
# AssetsCurrent                                    23073000000  44345000000
# PropertyPlantAndEquipmentNet                      3807000000   3914000000
# OperatingLeaseRightOfUseAsset                     1038000000   1346000000
# Goodwill                                          4372000000   4430000000
# IntangibleAssetsNetExcludingGoodwill              1676000000   1112000000
# DeferredIncomeTaxAssetsNet                        3396000000   6081000000
# OtherAssetsNoncurrent                             3820000000   4500000000
# Assets                                           41182000000  65728000000
# AccountsPayableCurrent                            1193000000   2699000000
# AccruedLiabilitiesCurrent                         4120000000   6682000000
# DebtCurrent                                       1250000000   1250000000
# LiabilitiesCurrent                                6563000000  10631000000
# LongTermDebtNoncurrent                            9703000000   8459000000
# OperatingLeaseLiabilityNoncurrent                  902000000   1119000000
# OtherLiabilitiesNoncurrent                        1913000000   2541000000
# Liabilities                                      19081000000  22750000000
# CommitmentsAndContingencies                              0.0          0.0
# PreferredStockValueOutstanding                             0            0
# CommonStockValue                                     2000000      2000000
# AdditionalPaidInCapital                          11971000000  13132000000
# AccumulatedOtherComprehensiveIncomeLossNetOfTax    -43000000     27000000
# RetainedEarningsAccumulatedDeficit               10171000000  29817000000
# StockholdersEquity                               22101000000  42978000000
# LiabilitiesAndStockholdersEquity                 41182000000  65728000000

# %% [markdown]
# ##### Cash flow statement

# %%
def get_cash_flow_statement(financial_statements_json):
    cash_flows_store = {}

    for usGaapItem in financial_statements_json['StatementsOfCashFlows']:
        values = []
        indicies = []

        for fact in financial_statements_json['StatementsOfCashFlows'][usGaapItem]:        
            # only consider items without segment.
            if 'segment' not in fact:
                # check if date instant or date range is present
                if "instant" in fact['period']:
                    index = fact['period']['instant']
                else:
                    index = fact['period']['startDate'] + '-' + fact['period']['endDate']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue

                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    

        cash_flows_store[usGaapItem] = pd.Series(values, index=indicies) 


    cash_flows = pd.DataFrame(cash_flows_store)
    return cash_flows.T
    
cash_flows = get_cash_flow_statement(financial_statements_json)
cash_flows
# Out:
#                                                    2021-01-31  \
# NetIncomeLoss                                             NaN
# ShareBasedCompensation                                    NaN
# DepreciationDepletionAndAmortization                      NaN
# DeferredIncomeTaxExpenseBenefit                           NaN
# GainLossOnInvestments                                     NaN
# BusinessCombinationAdvancedConsiderationWrittenOff        NaN
# OtherNoncashIncomeExpense                                 NaN
# IncreaseDecreaseInAccountsReceivable                      NaN
# IncreaseDecreaseInInventories                             NaN
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...        NaN
# IncreaseDecreaseInAccountsPayable                         NaN
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...        NaN
# IncreaseDecreaseInOtherNoncurrentLiabilities              NaN
# NetCashProvidedByUsedInOperatingActivities                NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...        NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt          NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt           NaN
# PaymentsToAcquireProductiveAssets                         NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired              NaN
# PaymentsForProceedsFromOtherInvestingActivities           NaN
# NetCashProvidedByUsedInInvestingActivities                NaN
# ProceedsFromStockPlans                                    NaN
# PaymentsForRepurchaseOfCommonStock                        NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...        NaN
# RepaymentsOfDebt                                          NaN
# PaymentsOfDividends                                       NaN
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...        NaN
# ProceedsFromDebtNetOfIssuanceCosts                        NaN
# ProceedsFromPaymentsForOtherFinancingActivities           NaN
# NetCashProvidedByUsedInFinancingActivities                NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...        NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...  847000000
# IncomeTaxesPaidNet                                        NaN
# InterestPaidNet                                           NaN
#
#                                                    2021-02-01-2022-01-30  \
# NetIncomeLoss                                                 9752000000
# ShareBasedCompensation                                        2004000000
# DepreciationDepletionAndAmortization                          1174000000
# DeferredIncomeTaxExpenseBenefit                               -406000000
# GainLossOnInvestments                                          100000000
# BusinessCombinationAdvancedConsiderationWrittenOff                     0
# OtherNoncashIncomeExpense                                      -47000000
# IncreaseDecreaseInAccountsReceivable                          2215000000
# IncreaseDecreaseInInventories                                  774000000
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            1715000000
# IncreaseDecreaseInAccountsPayable                              568000000
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...             581000000
# IncreaseDecreaseInOtherNoncurrentLiabilities                   192000000
# NetCashProvidedByUsedInOperatingActivities                    9108000000
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...           15197000000
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt              1023000000
# PaymentsToAcquireAvailableForSaleSecuritiesDebt              24787000000
# PaymentsToAcquireProductiveAssets                              976000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                   263000000
# PaymentsForProceedsFromOtherInvestingActivities                 24000000
# NetCashProvidedByUsedInInvestingActivities                   -9830000000
# ProceedsFromStockPlans                                         281000000
# PaymentsForRepurchaseOfCommonStock                                     0
# PaymentsRelatedToTaxWithholdingForShareBasedCom...            1904000000
# RepaymentsOfDebt                                              1000000000
# PaymentsOfDividends                                            399000000
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...              83000000
# ProceedsFromDebtNetOfIssuanceCosts                            4977000000
# ProceedsFromPaymentsForOtherFinancingActivities                 -7000000
# NetCashProvidedByUsedInFinancingActivities                    1865000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...            1143000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# IncomeTaxesPaidNet                                             396000000
# InterestPaidNet                                                246000000
#
#                                                     2022-01-30  \
# NetIncomeLoss                                              NaN
# ShareBasedCompensation                                     NaN
# DepreciationDepletionAndAmortization                       NaN
# DeferredIncomeTaxExpenseBenefit                            NaN
# GainLossOnInvestments                                      NaN
# BusinessCombinationAdvancedConsiderationWrittenOff         NaN
# OtherNoncashIncomeExpense                                  NaN
# IncreaseDecreaseInAccountsReceivable                       NaN
# IncreaseDecreaseInInventories                              NaN
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...         NaN
# IncreaseDecreaseInAccountsPayable                          NaN
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...         NaN
# IncreaseDecreaseInOtherNoncurrentLiabilities               NaN
# NetCashProvidedByUsedInOperatingActivities                 NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...         NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt           NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt            NaN
# PaymentsToAcquireProductiveAssets                          NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired               NaN
# PaymentsForProceedsFromOtherInvestingActivities            NaN
# NetCashProvidedByUsedInInvestingActivities                 NaN
# ProceedsFromStockPlans                                     NaN
# PaymentsForRepurchaseOfCommonStock                         NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...         NaN
# RepaymentsOfDebt                                           NaN
# PaymentsOfDividends                                        NaN
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...         NaN
# ProceedsFromDebtNetOfIssuanceCosts                         NaN
# ProceedsFromPaymentsForOtherFinancingActivities            NaN
# NetCashProvidedByUsedInFinancingActivities                 NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...         NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...  1990000000
# IncomeTaxesPaidNet                                         NaN
# InterestPaidNet                                            NaN
#
#                                                    2022-01-31-2023-01-29  \
# NetIncomeLoss                                                 4368000000
# ShareBasedCompensation                                        2709000000
# DepreciationDepletionAndAmortization                          1544000000
# DeferredIncomeTaxExpenseBenefit                              -2164000000
# GainLossOnInvestments                                          -45000000
# BusinessCombinationAdvancedConsiderationWrittenOff            1353000000
# OtherNoncashIncomeExpense                                        7000000
# IncreaseDecreaseInAccountsReceivable                          -822000000
# IncreaseDecreaseInInventories                                 2554000000
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            1517000000
# IncreaseDecreaseInAccountsPayable                             -551000000
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...            1341000000
# IncreaseDecreaseInOtherNoncurrentLiabilities                   252000000
# NetCashProvidedByUsedInOperatingActivities                    5641000000
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...           19425000000
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt              1806000000
# PaymentsToAcquireAvailableForSaleSecuritiesDebt              11897000000
# PaymentsToAcquireProductiveAssets                             1833000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                    49000000
# PaymentsForProceedsFromOtherInvestingActivities                 77000000
# NetCashProvidedByUsedInInvestingActivities                    7375000000
# ProceedsFromStockPlans                                         355000000
# PaymentsForRepurchaseOfCommonStock                           10039000000
# PaymentsRelatedToTaxWithholdingForShareBasedCom...            1475000000
# RepaymentsOfDebt                                                       0
# PaymentsOfDividends                                            398000000
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...              58000000
# ProceedsFromDebtNetOfIssuanceCosts                                     0
# ProceedsFromPaymentsForOtherFinancingActivities                 -2000000
# NetCashProvidedByUsedInFinancingActivities                  -11617000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...            1399000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# IncomeTaxesPaidNet                                            1404000000
# InterestPaidNet                                                254000000
#
#                                                     2023-01-29  \
# NetIncomeLoss                                              NaN
# ShareBasedCompensation                                     NaN
# DepreciationDepletionAndAmortization                       NaN
# DeferredIncomeTaxExpenseBenefit                            NaN
# GainLossOnInvestments                                      NaN
# BusinessCombinationAdvancedConsiderationWrittenOff         NaN
# OtherNoncashIncomeExpense                                  NaN
# IncreaseDecreaseInAccountsReceivable                       NaN
# IncreaseDecreaseInInventories                              NaN
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...         NaN
# IncreaseDecreaseInAccountsPayable                          NaN
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...         NaN
# IncreaseDecreaseInOtherNoncurrentLiabilities               NaN
# NetCashProvidedByUsedInOperatingActivities                 NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...         NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt           NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt            NaN
# PaymentsToAcquireProductiveAssets                          NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired               NaN
# PaymentsForProceedsFromOtherInvestingActivities            NaN
# NetCashProvidedByUsedInInvestingActivities                 NaN
# ProceedsFromStockPlans                                     NaN
# PaymentsForRepurchaseOfCommonStock                         NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...         NaN
# RepaymentsOfDebt                                           NaN
# PaymentsOfDividends                                        NaN
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...         NaN
# ProceedsFromDebtNetOfIssuanceCosts                         NaN
# ProceedsFromPaymentsForOtherFinancingActivities            NaN
# NetCashProvidedByUsedInFinancingActivities                 NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...         NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...  3389000000
# IncomeTaxesPaidNet                                         NaN
# InterestPaidNet                                            NaN
#
#                                                    2023-01-30-2024-01-28  \
# NetIncomeLoss                                                29760000000
# ShareBasedCompensation                                        3549000000
# DepreciationDepletionAndAmortization                          1508000000
# DeferredIncomeTaxExpenseBenefit                              -2489000000
# GainLossOnInvestments                                          238000000
# BusinessCombinationAdvancedConsiderationWrittenOff                     0
# OtherNoncashIncomeExpense                                      278000000
# IncreaseDecreaseInAccountsReceivable                          6172000000
# IncreaseDecreaseInInventories                                   98000000
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            1522000000
# IncreaseDecreaseInAccountsPayable                             1531000000
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...            2025000000
# IncreaseDecreaseInOtherNoncurrentLiabilities                   514000000
# NetCashProvidedByUsedInOperatingActivities                   28090000000
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...            9732000000
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt                50000000
# PaymentsToAcquireAvailableForSaleSecuritiesDebt              18211000000
# PaymentsToAcquireProductiveAssets                             1069000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                    83000000
# PaymentsForProceedsFromOtherInvestingActivities                985000000
# NetCashProvidedByUsedInInvestingActivities                  -10566000000
# ProceedsFromStockPlans                                         403000000
# PaymentsForRepurchaseOfCommonStock                            9533000000
# PaymentsRelatedToTaxWithholdingForShareBasedCom...            2783000000
# RepaymentsOfDebt                                              1250000000
# PaymentsOfDividends                                            395000000
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...              74000000
# ProceedsFromDebtNetOfIssuanceCosts                                     0
# ProceedsFromPaymentsForOtherFinancingActivities                 -1000000
# NetCashProvidedByUsedInFinancingActivities                  -13633000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...            3891000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...                   NaN
# IncomeTaxesPaidNet                                            6549000000
# InterestPaidNet                                                252000000
#
#                                                     2024-01-28
# NetIncomeLoss                                              NaN
# ShareBasedCompensation                                     NaN
# DepreciationDepletionAndAmortization                       NaN
# DeferredIncomeTaxExpenseBenefit                            NaN
# GainLossOnInvestments                                      NaN
# BusinessCombinationAdvancedConsiderationWrittenOff         NaN
# OtherNoncashIncomeExpense                                  NaN
# IncreaseDecreaseInAccountsReceivable                       NaN
# IncreaseDecreaseInInventories                              NaN
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...         NaN
# IncreaseDecreaseInAccountsPayable                          NaN
# IncreaseDecreaseInAccruedLiabilitiesAndOtherOpe...         NaN
# IncreaseDecreaseInOtherNoncurrentLiabilities               NaN
# NetCashProvidedByUsedInOperatingActivities                 NaN
# ProceedsFromMaturitiesPrepaymentsAndCallsOfAvai...         NaN
# ProceedsFromSaleOfAvailableForSaleSecuritiesDebt           NaN
# PaymentsToAcquireAvailableForSaleSecuritiesDebt            NaN
# PaymentsToAcquireProductiveAssets                          NaN
# PaymentsToAcquireBusinessesNetOfCashAcquired               NaN
# PaymentsForProceedsFromOtherInvestingActivities            NaN
# NetCashProvidedByUsedInInvestingActivities                 NaN
# ProceedsFromStockPlans                                     NaN
# PaymentsForRepurchaseOfCommonStock                         NaN
# PaymentsRelatedToTaxWithholdingForShareBasedCom...         NaN
# RepaymentsOfDebt                                           NaN
# PaymentsOfDividends                                        NaN
# PaymentsForFinancedPropertyPlantAndEquipmentAnd...         NaN
# ProceedsFromDebtNetOfIssuanceCosts                         NaN
# ProceedsFromPaymentsForOtherFinancingActivities            NaN
# NetCashProvidedByUsedInFinancingActivities                 NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...         NaN
# CashCashEquivalentsRestrictedCashAndRestrictedC...  7280000000
# IncomeTaxesPaidNet                                         NaN
# InterestPaidNet                                            NaN

# %% [markdown]
# ## 3. Generate graph nodes from 10K text

# %%
os.environ["NEO4J_URL"] = "bolt://localhost:7687"
os.environ["NEO4J_USERNAME"] = "neo4j"
os.environ["NEO4J_PASSWORD"] = "neo4j123456"
os.environ["NEO4J_DATABASE"] = "form10k"

# Global constants
VECTOR_INDEX_NAME = 'form_10k_chunks'
VECTOR_NODE_LABEL = 'Chunk'
VECTOR_SOURCE_PROPERTY = 'text'
VECTOR_EMBEDDING_PROPERTY = 'textEmbedding'

# %%
with open("nvda_10k_2023.json", "r") as f:
    filing_10k = json.load(f)

# %%
filing_10k.keys()
# Out:
# dict_keys(['name', 'ticker', 'cik', 'cusip', 'exchange', 'isDelisted', 'category', 'sector', 'industry', 'sic', 'sicSector', 'sicIndustry', 'famaSector', 'famaIndustry', 'currency', 'location', 'id', 'url', 'item1', 'item1A', 'item1B', 'item1C', 'item2', 'item3', 'item4', 'item5', 'item6', 'item7', 'item7A', 'item8', 'item9', 'item9A', 'item9B', 'item9C', 'item10', 'item11', 'item12', 'item13', 'item14', 'item15'])

# %% [markdown]
# ##### Split text to chunks

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 2000,
    chunk_overlap  = 200,
    length_function = len,
    is_separator_regex = False,
)

# %% [markdown]
# **Text embedding**

# %%
embeddings = OllamaEmbeddings(
    model="mxbai-embed-large:latest",  # 1024 dimensions
    # model="znbang/bge:large-en-v1.5-f16",   # 1024 dimensions
    # model="nomic-embed-text:latest",   # 768 dimensions
    num_gpu=1,
    num_thread=16,
)

embedded = embeddings.embed_query("some sample text chunk")

# %%
type(embedded), len(embedded)
# Out:
# (list, 1024)

# %%
extract_section_list = ['item1','item1A','item7','item7A', 'item15']

# %%
def split_form10k_data_from_file(file_as_object):
    chunks_with_metadata = [] # use this to accumlate chunk records
    for item in extract_section_list: # pull these keys from the json
        print(f'Processing {item}') 
        item_text = file_as_object[item] # grab the text of the item
        item_text_chunks = text_splitter.split_text(item_text) # split the text into chunks
        chunk_seq_id = 0
        for chunk in item_text_chunks: 
            form_id = file_as_object['id']
            # finally, construct a record with metadata and the chunk text
            chunks_with_metadata.append({
                'text': chunk, 
                # metadata from looping...
                'f10kItem': item,
                'chunkSeqId': chunk_seq_id,
                # constructed metadata...
                'formId': f'{form_id}', # pulled from the filename
                'chunkId': f'{form_id}-{item}-chunk{chunk_seq_id:04d}',
                # metadata from file...
                'name': file_as_object['name'],
                'cik': file_as_object['cik'],
                'cusip': file_as_object['cusip'],
                'source': file_as_object['url'],
                'textEmbedding': embeddings.embed_query(chunk)
            })
            chunk_seq_id += 1
        print(f'\tSplit into {chunk_seq_id} chunks')
    return chunks_with_metadata

# %%
filing_10k_chunks = split_form10k_data_from_file(filing_10k)
print(f'Total {len(filing_10k_chunks)} chunks')
# Out:
# Processing item1
# 	Split into 32 chunks
# Processing item1A
# 	Split into 75 chunks
# Processing item7
# 	Split into 25 chunks
# Processing item7A
# 	Split into 2 chunks
# Processing item15
# 	Split into 72 chunks
# Total 206 chunks

# %%
filing_10k_chunks[22]
# Out:
# {'text': 'Compliance with laws, rules, and regulations has not otherwise had a material effect upon our capital expenditures, results of operations, or competitive position and we do not currently anticipate material capital expenditures for environmental control facilities. Compliance with existing or future governmental regulations, including, but not limited to, those pertaining to IP ownership and infringement, taxes, import and export requirements and tariffs, anti-corruption, business acquisitions, foreign exchange controls and cash repatriation restrictions, data privacy requirements, competition and antitrust, advertising, employment, product regulations, cybersecurity, environmental, health and safety requirements, the responsible use of AI, climate change, cryptocurrency, and consumer laws, could increase our costs, impact our competitive position, and otherwise may have a material adverse impact on our business, financial condition and results of operations in subsequent periods. Refer to &#8220;Item 1A. Risk Factors&#8221; for a discussion of these potential impacts. \n\nSustainability and Governance \n\nNVIDIA invents computing technologies that improve lives and address global challenges. Our goal is to integrate sound environmental, social, and corporate governance principles and practices into every aspect of the Company. The Nominating and Corporate Governance Committee of our Board of Directors is responsible for reviewing and discussing with management our practices related to sustainability and corporate governance. We assess our programs annually in consideration of stakeholder expectations, market trends, and business risks and opportunities. These issues are important for our continued business success and reflect the topics of highest concern to NVIDIA and our stakeholders.',
#  'f10kItem': 'item1',
#  'chunkSeqId': 22,
#  'formId': '4a73b69083f93d38e05e0b76219875c9',
#  'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk
#   -0.29422807693481445,
#   0.5441938638687134,
#   -0.3710029125213623,
#   -0.12550696730613708,
#   0.45798927545547485,
#   -0.016991935670375824,
#   0.34091222286224365,
#   0.7503464221954346,
#   -0.30152904987335205,
#   0.27661484479904175,
#   0.7231059074401855,
#   0.11553715169429779,
#   0.9364980459213257,
#   -1.0288914442062378,
#   0.5571804046630859,
#   0.90259850025177,
#   -0.34870821237564087,
#   0.11372837424278259,
#   -0.7668444514274597,
#   -0.27437669038772583,
#   -0.37774956226348877,
#   -0.01818639039993286,
#   0.5817707180976868,
#   -0.2620702385902405,
#   0.4360022246837616,
#   -0.13649943470954895,
#   0.29267391562461853,
#   0.3647956848144531,
#   -0.22023636102676392,
#   0.2266758680343628,
#   -0.1795659065246582,
#   0.27992501854896545,
#   -0.24992820620536804,
#   ...]}

# %% [markdown]
# ### 3.1 Create graph nodes using text chunks

# %%
kg = Neo4jGraph(
    url=os.getenv("NEO4J_URL"), 
    username=os.getenv("NEO4J_USERNAME"), 
    password=os.getenv("NEO4J_PASSWORD"), 
    database=os.getenv("NEO4J_DATABASE"),
)

# %%
kg.schema
# Out:
# 'Node properties:\nChunk {textEmbedding: LIST, name: STRING, cusip: STRING, f10kItem: STRING, chunkSeqId: INTEGER, text: STRING, formId: STRING, chunkId: STRING, cik: STRING, source: STRING}\nForm {formId: STRING, cusip: STRING, cik: STRING, source: STRING, name: STRING}\nRelationship properties:\nSECTION {f10kItem: STRING}\nThe relationships:\n(:Chunk)-[:NEXT]->(:Chunk)\n(:Form)-[:SECTION]->(:Chunk)'

# %%
# test purpose, delete existing data to reset
if kg.query("match p=()-->() return count(p) as isExist")[0]['isExist'] > 0:
    kg.query(
        """
        MATCH p=()-->()
        DETACH DELETE p
        """
    )
    print(kg.query("match p=()-->() return count(p) as isExist")[0]['isExist'])

# delete existing indexes
kg.query("CALL apoc.schema.assert({},{},true) YIELD label, key RETURN *")
# kg.query("DROP INDEX vector")    # use this cypher in neo4j browser to delete index one by one
# Out:
# []

# %% [markdown]
# **Create a uniqueness constraint to avoid duplicate chunks**

# %%
index_name = "unique_chunk"

kg.query(f"""
CREATE CONSTRAINT {index_name} IF NOT EXISTS 
    FOR (c:Chunk) REQUIRE c.chunkId IS UNIQUE
""")
# Out:
# []

# %%
# check if constraint/index created successfully

kg.query(f"""
SHOW INDEXes yield * 
where name CONTAINS "{index_name}"
return name, createStatement
""")
# Out:
# [{'name': 'unique_chunk',
#   'createStatement': 'CREATE CONSTRAINT `unique_chunk` FOR (n:`Chunk`) REQUIRE (n.`chunkId`) IS UNIQUE'}]

# %%
kg.query("SHOW CONSTRAINT")
# Out:
# [{'id': 4,
#   'name': 'unique_chunk',
#   'type': 'UNIQUENESS',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['chunkId'],
#   'ownedIndex': 'unique_chunk',
#   'propertyType': None}]

# %% [markdown]
# **Create nodes for chunks**

# %%
# test purpose, delete existing data to reset
if kg.query("match (n) return count(n) as isExist")[0]['isExist'] > 0:
    n_nodes = kg.query('match (n) return count(n) as isExist')[0]['isExist']
    print(f"{n_nodes} nodes exist.")
    print("Deleting existing nodes...")
    kg.query(
        """
        MATCH (n)
        DETACH DELETE n
        """
    )
    print("All nodes deleted.")

# %% [markdown]
# **Calculate embedding vectors for chunks and populate index**
# - This query calculates the embedding vector and stores it as a property called `textEmbedding` on each `Chunk` node.

# %%
merge_chunk_node_query = """
MERGE(mergedChunk
# Creating `:Chunk` node for chunk ID 4a73b69083f93d38e05e0b76219875c9-item15-chunk0070
# Creating `:Chunk` node for chunk ID 4a73b69083f93d38e05e0b76219875c9-item15-chunk0071
# Created 206 nodes

# %% [markdown]
# ### 3.2 Create vector index on textEmbedding

# %%
dimensions = len(embedded)    # nomic 768, mxbai 1024, openai 1536

kg.query("""
         CREATE VECTOR INDEX $VECTOR_INDEX_NAME IF NOT EXISTS
          FOR (c:Chunk) ON (c.textEmbedding) 
          OPTIONS { indexConfig: {
            `vector.dimensions`: $dimensions,
            `vector.similarity_function`: 'cosine'    
         }}
""", params = {
    "VECTOR_INDEX_NAME": VECTOR_INDEX_NAME, 
    "dimensions": dimensions})
# Out:
# []

# %%
kg.query("""
SHOW INDEXES yield * 
where name CONTAINS $VECTOR_INDEX_NAME
return name, createStatement
""", params={"VECTOR_INDEX_NAME": VECTOR_INDEX_NAME, })
# Out:
# [{'name': 'form_10k_chunks',
#   'createStatement': "CREATE VECTOR INDEX `form_10k_chunks` FOR (n:`Chunk`) ON (n.`textEmbedding`) OPTIONS {indexConfig: {`vector.dimensions`: 1024,`vector.similarity_function`: 'COSINE'}, indexProvider: 'vector-2.0'}"}]

# %%
kg.query("SHOW VECTOR INDEXES")
# Out:
# [{'id': 6,
#   'name': 'form_10k_chunks',
#   'state': 'ONLINE',
#   'populationPercent': 100.0,
#   'type': 'VECTOR',
#   'entityType': 'NODE',
#   'labelsOrTypes': ['Chunk'],
#   'properties': ['textEmbedding'],
#   'indexProvider': 'vector-2.0',
#   'owningConstraint': None,
#   'lastRead': None,
#   'readCount': None}]

# %%
kg.refresh_schema()
print(kg.schema)
# Out:
# Node properties:
# Chunk {textEmbedding: LIST, name: STRING, cusip: STRING, f10kItem: STRING, chunkSeqId: INTEGER, text: STRING, formId: STRING, chunkId: STRING, cik: STRING, source: STRING}
# Form {formId: STRING, cusip: STRING, cik: STRING, source: STRING, name: STRING}
# Relationship properties:
# SECTION {f10kItem: STRING}
# The relationships:
# (:Chunk)-[:NEXT]->(:Chunk)
# (:Form)-[:SECTION]->(:Chunk)

# %% [markdown]
# **Use similarity search to find relevant chunks**
# - Setup a help function to perform similarity search using the vector index

# %%
def neo4j_vector_search(question):
  """Search for similar nodes using the Neo4j vector index"""
  vector_search_query = """
    CALL db.index.vector.queryNodes($index_name, $top_k, $question_embedding) yield node, score
    RETURN score, node.chunkId as chunkId, node.text AS text
  """
  similar = kg.query(vector_search_query, 
                     params={ 
                      'index_name':VECTOR_INDEX_NAME, 
                      'top_k': 10,
                      'question_embedding': embeddings.embed_query(question)
                      })
  return similar

# %%
search_results = neo4j_vector_search(
    'In a single sentence, tell me about Nvidia gross margin.'
)

# %%
search_results[:2]
# Out:
# [{'score': 0.8009248375892639,
#   'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0052',
#   'text': 'case, which NVIDIA had filed on October 10, 2023. On November 21, 2023, NVIDIA filed a motion with the Ninth Circuit for a stay of the mandate pending NVIDIA&#8217;s petition for a writ of certiorari in the Supreme Court of the United States and the Supreme Court&#8217;s'},
#  {'score': 0.7841192483901978,
#   'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0000',
#   'text': 'Item 7. Management\'s Discussion and Analysis of Financial Condition and Results of Operations \n\nThe following discussion and analysis of our financial condition and results of operations should be read in conjunction with &#8220;Item 1A. Risk Factors&#8221;, our Consolidated Financial Statements and related Notes thereto, as well as other cautionary statements and risks described elsewhere in this Annual Report on Form 10-K, before deciding to purchase, hold or sell shares of our common stock. \n\nOverview \n\nOur Company and Our Businesses \n\nNVIDIA pioneered accelerated computing to help solve the most challenging computational problems. Since our original focus on PC graphics, we have expanded to several other large and important computationally intensive fields. NVIDIA has leveraged its GPU architecture to create platforms for accelerated computing, AI solutions, scientific computing, data science, AV, robotics, metaverse and 3D internet applications. \n\nOur two operating segments are "Compute &#38; Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial Statements in Part IV, Item 15 of this Annual Report on Form 10-K for additional information. \n\nHeadquartered in Santa Clara, California, NVIDIA was incorporated in California in April 1993 and reincorporated in Delaware in April 1998. \n\nRecent Developments, Future Objectives and Challenges \n\nDemand and Supply, Product Transitions, and New Products and Business Models'}]

# %% [markdown]
# ##### RAG chat with the form

# %%
neo4j_vector_store = Neo4jVector.from_existing_graph(
    embedding=embeddings,
    url=os.getenv("NEO4J_URL"),
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD"),
    database=os.getenv("NEO4J_DATABASE"),
    index_name=VECTOR_INDEX_NAME,
    node_label=VECTOR_NODE_LABEL,
    text_node_properties=[VECTOR_SOURCE_PROPERTY],
    embedding_node_property=VECTOR_EMBEDDING_PROPERTY,
)

# %%
retriever = neo4j_vector_store.as_retriever()

# %% [markdown]
# * Set up a RetrievalQAWithSourcesChain to carry out question answering

# %%
chain = RetrievalQAWithSourcesChain.from_chain_type(
    ChatGroq(temperature=0), 
    chain_type="stuff", 
    retriever=retriever
)

# %%
def prettychain(question: str) -> str:
    """Pretty print the chain's response to a question"""
    response = chain.invoke({
        "system" : "If you don't know the answer, just say you don't know.", 
        "question": question},
        return_only_outputs=True,)
    print(textwrap.fill(response['answer'], 60))

# %%
prettychain("Where is Nvidia headquartered?")
# Out:
# Nvidia is headquartered in Santa Clara, California.

# %%
prettychain("What is Nvidia primary business?")
# Out:
# Nvidia's primary business is pioneering accelerated
# computing to help solve complex computational problems in
# several large and important computationally intensive
# fields. They have leveraged their GPU architecture to create
# platforms for accelerated computing, AI solutions,
# scientific computing, data science, AV, robotics, metaverse
# and 3D internet applications. Their two main operating
# segments are "Compute & Networking" and "Graphics."

# %%
prettychain("Nvidia's gross margin in 2023")
# Out:
# There is no information provided in the sources that allows
# me to determine Nvidia's gross margin in 2023.

# %% [markdown]
# ## 4. Adding Relationships to graph of 10k

# %% [markdown]
# **Create a Form 10-K node**
# - Create a node to represent the entire Form 10-K
# - Populate with metadata taken from a single chunk of the form

# %%
cypher = """
  MATCH (anyChunk:Chunk) 
  WITH anyChunk LIMIT 1
  RETURN anyChunk { .name, .source, .formId, .cik, .cusip } as formInfo
"""
form_info_list = kg.query(cypher)

form_info_list
# Out:
# [{'formInfo': {'cik': '1045810',
#    'source': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm',
#    'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'name': 'NVIDIA CORP',
#    'cusip': '67066G104'}}]

# %%
form_info = form_info_list[0]['formInfo']
form_info
# Out:
# {'cik': '1045810',
#  'source': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000029/nvda-20240128.htm',
#  'formId': '4a73b69083f93d38e05e0b76219875c9',
#  'name': 'NVIDIA CORP',
#  'cusip': '67066G104'}

# %%
cypher = """
    MERGE (f:Form {formId: $formInfoParam.formId })
      ON CREATE 
        SET f.name = $formInfoParam.name
        SET f.source = $formInfoParam.source
        SET f.cik = $formInfoParam.cik
        SET f.cusip = $formInfoParam.cusip
"""

kg.query(cypher, params={'formInfoParam': form_info})
# Out:
# []

# %%
kg.query("MATCH (f:Form) RETURN count(f) as formCount")
# Out:
# [{'formCount': 1}]

# %% [markdown]
# **Create a linked list of Chunk nodes for each section(e.g. item1, item1A)**
# - Start by identifying chunks from the same section

# %%
cypher = """
  MATCH (from_same_form:Chunk)
    WHERE from_same_form.formId = $formIdParam
  RETURN from_same_form {.formId, .f10kItem, .chunkId, .chunkSeqId } as chunkInfo
"""

kg.query(cypher, params={'formIdParam': form_info['formId']})
# Out:
# [{'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0001',
#    'chunkSeqId': 1}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0002',
#    'chunkSeqId': 2}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0003',
#    'chunkSeqId': 3}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0004',
#    'chunkSeqId': 4}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0005',
#    'chunkSeqId': 5}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0006',
#    'chunkSeqId': 6}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0007',
#    'chunkSeqId': 7}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0008',
#    'chunkSeqId': 8}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0009',
#    'chunkSeqId': 9}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0010',
#    'chunkSeqId': 10}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0011',
#    'chunkSeqId': 11}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0012',
#    'chunkSeqId': 12}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0013',
#    'chunkSeqId': 13}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0014',
#    'chunkSeqId': 14}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0015',
#    'chunkSeqId': 15}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0016',
#    'chunkSeqId': 16}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0017',
#    'chunkSeqId': 17}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0018',
#    'chunkSeqId': 18}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0019',
#    'chunkSeqId': 19}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0020',
#    'chunkSeqId': 20}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0021',
#    'chunkSeqId': 21}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0022',
#    'chunkSeqId': 22}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0023',
#    'chunkSeqId': 23}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0024',
#    'chunkSeqId': 24}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0025',
#    'chunkSeqId': 25}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0026',
#    'chunkSeqId': 26}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0027',
#    'chunkSeqId': 27}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0028',
#    'chunkSeqId': 28}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0029',
#    'chunkSeqId': 29}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0030',
#    'chunkSeqId': 30}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0031',
#    'chunkSeqId': 31}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0000',
#    'chunkSeqId': 0}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0001',
#    'chunkSeqId': 1}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0002',
#    'chunkSeqId': 2}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0003',
#    'chunkSeqId': 3}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0004',
#    'chunkSeqId': 4}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0005',
#    'chunkSeqId': 5}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0006',
#    'chunkSeqId': 6}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0007',
#    'chunkSeqId': 7}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0008',
#    'chunkSeqId': 8}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0009',
#    'chunkSeqId': 9}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0010',
#    'chunkSeqId': 10}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0011',
#    'chunkSeqId': 11}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0012',
#    'chunkSeqId': 12}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0013',
#    'chunkSeqId': 13}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0014',
#    'chunkSeqId': 14}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0015',
#    'chunkSeqId': 15}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0016',
#    'chunkSeqId': 16}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0017',
#    'chunkSeqId': 17}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0018',
#    'chunkSeqId': 18}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0019',
#    'chunkSeqId': 19}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0020',
#    'chunkSeqId': 20}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0021',
#    'chunkSeqId': 21}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0022',
#    'chunkSeqId': 22}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0023',
#    'chunkSeqId': 23}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0024',
#    'chunkSeqId': 24}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0025',
#    'chunkSeqId': 25}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0026',
#    'chunkSeqId': 26}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0027',
#    'chunkSeqId': 27}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0028',
#    'chunkSeqId': 28}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0029',
#    'chunkSeqId': 29}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0030',
#    'chunkSeqId': 30}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0031',
#    'chunkSeqId': 31}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0032',
#    'chunkSeqId': 32}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0033',
#    'chunkSeqId': 33}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0034',
#    'chunkSeqId': 34}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0035',
#    'chunkSeqId': 35}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0036',
#    'chunkSeqId': 36}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0037',
#    'chunkSeqId': 37}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0038',
#    'chunkSeqId': 38}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0039',
#    'chunkSeqId': 39}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0040',
#    'chunkSeqId': 40}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0041',
#    'chunkSeqId': 41}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0042',
#    'chunkSeqId': 42}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0043',
#    'chunkSeqId': 43}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0044',
#    'chunkSeqId': 44}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0045',
#    'chunkSeqId': 45}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0046',
#    'chunkSeqId': 46}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0047',
#    'chunkSeqId': 47}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0048',
#    'chunkSeqId': 48}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0049',
#    'chunkSeqId': 49}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0050',
#    'chunkSeqId': 50}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0051',
#    'chunkSeqId': 51}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0052',
#    'chunkSeqId': 52}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0053',
#    'chunkSeqId': 53}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0054',
#    'chunkSeqId': 54}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0055',
#    'chunkSeqId': 55}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0056',
#    'chunkSeqId': 56}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0057',
#    'chunkSeqId': 57}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0058',
#    'chunkSeqId': 58}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0059',
#    'chunkSeqId': 59}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0060',
#    'chunkSeqId': 60}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0061',
#    'chunkSeqId': 61}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0062',
#    'chunkSeqId': 62}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0063',
#    'chunkSeqId': 63}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0064',
#    'chunkSeqId': 64}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0065',
#    'chunkSeqId': 65}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0066',
#    'chunkSeqId': 66}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0067',
#    'chunkSeqId': 67}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0068',
#    'chunkSeqId': 68}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0069',
#    'chunkSeqId': 69}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0070',
#    'chunkSeqId': 70}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0071',
#    'chunkSeqId': 71}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0072',
#    'chunkSeqId': 72}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0073',
#    'chunkSeqId': 73}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1A-chunk0074',
#    'chunkSeqId': 74}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0000',
#    'chunkSeqId': 0}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0001',
#    'chunkSeqId': 1}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0002',
#    'chunkSeqId': 2}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0003',
#    'chunkSeqId': 3}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0004',
#    'chunkSeqId': 4}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0005',
#    'chunkSeqId': 5}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0006',
#    'chunkSeqId': 6}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0007',
#    'chunkSeqId': 7}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0008',
#    'chunkSeqId': 8}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0009',
#    'chunkSeqId': 9}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0010',
#    'chunkSeqId': 10}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0011',
#    'chunkSeqId': 11}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0012',
#    'chunkSeqId': 12}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0013',
#    'chunkSeqId': 13}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0014',
#    'chunkSeqId': 14}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0015',
#    'chunkSeqId': 15}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0016',
#    'chunkSeqId': 16}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0017',
#    'chunkSeqId': 17}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0018',
#    'chunkSeqId': 18}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0019',
#    'chunkSeqId': 19}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0020',
#    'chunkSeqId': 20}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0021',
#    'chunkSeqId': 21}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0022',
#    'chunkSeqId': 22}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0023',
#    'chunkSeqId': 23}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0024',
#    'chunkSeqId': 24}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7A-chunk0000',
#    'chunkSeqId': 0}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item7A',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7A-chunk0001',
#    'chunkSeqId': 1}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0000',
#    'chunkSeqId': 0}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0001',
#    'chunkSeqId': 1}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0002',
#    'chunkSeqId': 2}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0003',
#    'chunkSeqId': 3}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0004',
#    'chunkSeqId': 4}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0005',
#    'chunkSeqId': 5}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0006',
#    'chunkSeqId': 6}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0007',
#    'chunkSeqId': 7}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0008',
#    'chunkSeqId': 8}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0009',
#    'chunkSeqId': 9}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0010',
#    'chunkSeqId': 10}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0011',
#    'chunkSeqId': 11}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0012',
#    'chunkSeqId': 12}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0013',
#    'chunkSeqId': 13}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0014',
#    'chunkSeqId': 14}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0015',
#    'chunkSeqId': 15}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0016',
#    'chunkSeqId': 16}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0017',
#    'chunkSeqId': 17}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0018',
#    'chunkSeqId': 18}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0019',
#    'chunkSeqId': 19}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0020',
#    'chunkSeqId': 20}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0021',
#    'chunkSeqId': 21}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0022',
#    'chunkSeqId': 22}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0023',
#    'chunkSeqId': 23}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0024',
#    'chunkSeqId': 24}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0025',
#    'chunkSeqId': 25}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0026',
#    'chunkSeqId': 26}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0027',
#    'chunkSeqId': 27}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0028',
#    'chunkSeqId': 28}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0029',
#    'chunkSeqId': 29}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0030',
#    'chunkSeqId': 30}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0031',
#    'chunkSeqId': 31}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0032',
#    'chunkSeqId': 32}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0033',
#    'chunkSeqId': 33}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0034',
#    'chunkSeqId': 34}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0035',
#    'chunkSeqId': 35}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0036',
#    'chunkSeqId': 36}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0037',
#    'chunkSeqId': 37}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0038',
#    'chunkSeqId': 38}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0039',
#    'chunkSeqId': 39}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0040',
#    'chunkSeqId': 40}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0041',
#    'chunkSeqId': 41}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0042',
#    'chunkSeqId': 42}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0043',
#    'chunkSeqId': 43}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0044',
#    'chunkSeqId': 44}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0045',
#    'chunkSeqId': 45}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0046',
#    'chunkSeqId': 46}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0047',
#    'chunkSeqId': 47}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0048',
#    'chunkSeqId': 48}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0049',
#    'chunkSeqId': 49}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0050',
#    'chunkSeqId': 50}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0051',
#    'chunkSeqId': 51}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0052',
#    'chunkSeqId': 52}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0053',
#    'chunkSeqId': 53}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0054',
#    'chunkSeqId': 54}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0055',
#    'chunkSeqId': 55}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0056',
#    'chunkSeqId': 56}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0057',
#    'chunkSeqId': 57}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0058',
#    'chunkSeqId': 58}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0059',
#    'chunkSeqId': 59}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0060',
#    'chunkSeqId': 60}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0061',
#    'chunkSeqId': 61}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0062',
#    'chunkSeqId': 62}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0063',
#    'chunkSeqId': 63}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0064',
#    'chunkSeqId': 64}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0065',
#    'chunkSeqId': 65}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0066',
#    'chunkSeqId': 66}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0067',
#    'chunkSeqId': 67}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0068',
#    'chunkSeqId': 68}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0069',
#    'chunkSeqId': 69}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0070',
#    'chunkSeqId': 70}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item15',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item15-chunk0071',
#    'chunkSeqId': 71}},
#  {'chunkInfo': {'formId': '4a73b69083f93d38e05e0b76219875c9',
#    'f10kItem': 'item1',
#    'chunkId': '4a73b69083f93d38e05e0b76219875c9-item1-chunk0000',
#    'chunkSeqId': 0}}]

# %% [markdown]
# **Add a NEXT relationship between subsequent chunks within each sector**
# - Use the apoc.nodes.link function from Neo4j to link ordered list of Chunk nodes with a NEXT relationship
# - Loop thru all sections

# %%
cypher = """
  MATCH (from_same_section:Chunk)
  WHERE from_same_section.formId = $formIdParam
    AND from_same_section.f10kItem = $f10kItemParam
  WITH from_same_section
    ORDER BY from_same_section.chunkSeqId ASC
  WITH collect(from_same_section) as section_chunk_list
    CALL apoc.nodes.link(
        section_chunk_list, 
        "NEXT", 
        {avoidDuplicates: true}
    )  
  RETURN size(section_chunk_list)
"""

for section in extract_section_list:
    kg.query(cypher, params={'formIdParam': form_info['formId'], 
                         'f10kItemParam': section})

# %% [markdown]
# **Create a SECTION relationship on first chunk of each section**

# %%
cypher = """
  MATCH (first:Chunk), (f:Form)
  WHERE first.formId = f.formId
    AND first.chunkSeqId = 0
  WITH first, f
    MERGE (f)-[r:SECTION {f10kItem: first.f10kItem}]->(first)
  RETURN count(r)
"""

kg.query(cypher)
# Out:
# [{'count(r)': 5}]

# %%
kg.refresh_schema()
print(kg.schema)
# Out:
# Node properties:
# Chunk {textEmbedding: LIST, name: STRING, cusip: STRING, f10kItem: STRING, chunkSeqId: INTEGER, text: STRING, formId: STRING, chunkId: STRING, cik: STRING, source: STRING}
# Form {formId: STRING, cusip: STRING, cik: STRING, source: STRING, name: STRING}
# Relationship properties:
# SECTION {f10kItem: STRING}
# The relationships:
# (:Chunk)-[:NEXT]->(:Chunk)
# (:Form)-[:SECTION]->(:Chunk)

# %% [markdown]
# **check if the relationships are working**
# - Return the first chunk of the Item 1 section

# %%
cypher = """
  MATCH (f:Form)-[r:SECTION]->(first:Chunk)
    WHERE f.formId = $formIdParam
        AND r.f10kItem = $f10kItemParam
  RETURN first.chunkId as chunkId, first.text as text
"""

first_chunk_info = kg.query(cypher, params={
    'formIdParam': form_info['formId'], 
    'f10kItemParam': 'item7'
})[0]

first_chunk_info
# Out:
# {'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0000',
#  'text': 'Item 7. Management\'s Discussion and Analysis of Financial Condition and Results of Operations \n\nThe following discussion and analysis of our financial condition and results of operations should be read in conjunction with &#8220;Item 1A. Risk Factors&#8221;, our Consolidated Financial Statements and related Notes thereto, as well as other cautionary statements and risks described elsewhere in this Annual Report on Form 10-K, before deciding to purchase, hold or sell shares of our common stock. \n\nOverview \n\nOur Company and Our Businesses \n\nNVIDIA pioneered accelerated computing to help solve the most challenging computational problems. Since our original focus on PC graphics, we have expanded to several other large and important computationally intensive fields. NVIDIA has leveraged its GPU architecture to create platforms for accelerated computing, AI solutions, scientific computing, data science, AV, robotics, metaverse and 3D internet applications. \n\nOur two operating segments are "Compute &#38; Networking" and "Graphics." Refer to Note 17 of the Notes to the Consolidated Financial Statements in Part IV, Item 15 of this Annual Report on Form 10-K for additional information. \n\nHeadquartered in Santa Clara, California, NVIDIA was incorporated in California in April 1993 and reincorporated in Delaware in April 1998. \n\nRecent Developments, Future Objectives and Challenges \n\nDemand and Supply, Product Transitions, and New Products and Business Models'}

# %%
cypher = """
  MATCH (first:Chunk)-[:NEXT]->(nextChunk:Chunk)
    WHERE first.chunkId = $chunkIdParam
  RETURN nextChunk.chunkId as chunkId, nextChunk.text as text
"""

next_chunk_info = kg.query(cypher, params={
    'chunkIdParam': first_chunk_info['chunkId']
})[0]

next_chunk_info
# Out:
# {'chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0001',
#  'text': 'Recent Developments, Future Objectives and Challenges \n\nDemand and Supply, Product Transitions, and New Products and Business Models \n\nDemand for our data center systems and products surged in fiscal year 2024. Entering fiscal year 2025, we are gathering customer demand indications across several product transitions. We have demand visibility for our new data center products ramping later in fiscal year 2025. We have increased our supply and capacity purchases with existing suppliers, added new vendors and entered into prepaid manufacturing and capacity agreements. These increased purchase volumes, the number of suppliers, and the integration of new vendors into our supply chain may create more complexity and execution risk. Our purchase commitments and obligations for inventory and manufacturing capacity at the end of fiscal year 2024 were impacted by shortening lead times for certain components. We may continue to enter into new supplier and capacity arrangements. Supply of Hopper architecture products is improving, and demand remains very strong. We expect our next-generation products to be supply-constrained based upon demand indications. We may incur inventory provisions or impairments if our inventory or supply or capacity commitments exceed demand for our products or demand declines. \n\nWe build finished products and maintain inventory in advance of anticipated demand. While we have entered into long-term supply and capacity commitments, we may not be able to secure sufficient commitments for capacity to address our business needs, or our long-term demand expectations may change. These risks may increase as we shorten our product development cycles, enter new lines of business, or integrate new suppliers or components into our supply chain, creating additional supply chain complexity.'}

# %%
print(first_chunk_info['chunkId'],)
print(next_chunk_info['chunkId'])
# Out:
# 4a73b69083f93d38e05e0b76219875c9-item7-chunk0000
# 4a73b69083f93d38e05e0b76219875c9-item7-chunk0001

# %% [markdown]
# **Return a window of three chunks**

# %%
cypher = """
    MATCH (c1:Chunk)-[:NEXT]->(c2:Chunk)-[:NEXT]->(c3:Chunk) 
        WHERE c2.chunkId = $chunkIdParam
    RETURN c1.chunkId, c2.chunkId, c3.chunkId
    """

kg.query(cypher,
         params={'chunkIdParam': next_chunk_info['chunkId']})
# Out:
# [{'c1.chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0000',
#   'c2.chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0001',
#   'c3.chunkId': '4a73b69083f93d38e05e0b76219875c9-item7-chunk0002'}]

# %% [markdown]
# **windowPathLength**
# - number of relationships in the path

# %%
cypher = """
    MATCH window = (c1:Chunk)-[:NEXT]->(c2:Chunk)-[:NEXT]->(c3:Chunk) 
        WHERE c1.chunkId = $chunkIdParam
    RETURN length(window) as windowPathLength
    """

kg.query(cypher,
         params={'chunkIdParam': next_chunk_info['chunkId']})
# Out:
# [{'windowPathLength': 2}]

# %% [markdown]
# **Finding variable length windows**

# %%
# Modify ```NEXT``` relationship to have variable length

cypher = """
  MATCH window=
      (:Chunk)-[:NEXT*0..1]->(c:Chunk)-[:NEXT*0..2]->(:Chunk) 
    WHERE c.chunkId = $chunkIdParam
  RETURN length(window)
  """

kg.query(cypher,
         params={'chunkIdParam': next_chunk_info['chunkId']})
# Out:
# [{'length(window)': 0},
#  {'length(window)': 1},
#  {'length(window)': 2},
#  {'length(window)': 1},
#  {'length(window)': 2},
#  {'length(window)': 3}]

# %%
# retrieve only the longest path

cypher = """
  MATCH window=
      (:Chunk)-[:NEXT*0..1]->(c:Chunk)-[:NEXT*0..1]->(:Chunk)
    WHERE c.chunkId = $chunkIdParam
  WITH window as longestChunkWindow 
      ORDER BY length(window) DESC LIMIT 1
  RETURN length(longestChunkWindow)
  """

kg.query(cypher,
         params={'chunkIdParam': next_chunk_info['chunkId']})
# Out:
# [{'length(longestChunkWindow)': 2}]

# %%
prettychain("""What risk factors will impact Nvidia and why?
            If you don't know, just say you don't know.""")
# Out:
# Nvidia's risk factors include demand and supply challenges,
# product transitions, and new products and business models.
# These risks could impact the company's financial condition
# and results of operations. Additionally, the termination of
# the Arm Share Purchase Agreement resulted in a termination
# cost of $1.4 billion in fiscal year 2023. Nvidia operates in
# two segments: Compute & Networking and Graphics, addressing
# four large markets where its computing platforms can provide
# significant acceleration for applications.

# %%
prettychain("""How did Nvidia do in terms of its financial performance in 2023?
            If you don't know, just say you don't know.""")
# Out:
# I don't have the specific information about Nvidia's
# financial performance in 2023. The provided content includes
# financial statements and reports up to the year 2024, but it
# does not include the financial performance details for the
# year 2023.

# %%
prettychain("""How are Nvidia Corporation and Registrant related""")
# Out:
# Nvidia Corporation and Registrant are the same entity. The
# term "Registrant" is used to refer to Nvidia Corporation in
# the provided document, which is a filing made by Nvidia
# Corporation with the U.S. Securities and Exchange Commission
# (SEC).

# %%
prettychain("""How are Nvidia and Registrant related""")
# Out:
# Based on the provided content, NVIDIA Corporation is a
# company that operates in the technology sector, specializing
# in markets where its computing platforms can provide
# significant acceleration for applications. The company
# operates in four large markets: Data Center, Gaming,
# Professional Visualization, and Automotive. There is no
# direct mention of a "Registrant" in the provided content,
# and the relationship between NVIDIA and a "Registrant" is
# not clear from the context.

# %%
prettychain("""How are Nvidia and Xiaomi related""")
# Out:
# There is no direct relationship between Nvidia and Xiaomi
# mentioned in the provided sources.
